# %%
import requests as re
import pandas as pd

# %%
resp=re.get('https://newsapi.org/v2/everything?q=tesla&from=2021-08-19&sortBy=publishedAt&apiKey=c3d211cb92fe444492adc1bf751626ca')

# %%
resp
# Out:
# <Response [200]>

# %%
resp.json()
# Out:
# {'status': 'ok',
#  'totalResults': 10189,
#  'articles': [{'source': {'id': None, 'name': 'N-tv.de'},
#    'author': 'n-tv NACHRICHTEN',
#    'title': 'SpaceX-Kapsel sicher gelandet: Touristen kehren nach drei Tagen aus All zurück',
#    'description': 'Es war nicht der erste kommerzielle Passagierflug ins All, aber mit Abstand der längste und weiteste. Drei Tage lang umrundeten vier Weltraumtouristen mit der SpaceX-Kapsel "Crew Dragon" die Erde. Nach der Rückkehr berichten sie von einer "Wahnsinnsreise".',
#    'url': 'https://www.n-tv.de/panorama/Touristen-kehren-nach-drei-Tagen-aus-All-zurueck-article22812774.html',
#    'urlToImage': 'https://bilder2.n-tv.de/img/incoming/crop22812777/8061327535-cImg_16_9-w1200/257196719.jpg',
#    'publishedAt': '2021-09-19T05:33:29Z',
# ...

# %%
art=resp.json()['articles']

# %%
art
# Out:
# [{'source': {'id': None, 'name': 'N-tv.de'},
#   'author': 'n-tv NACHRICHTEN',
#   'title': 'SpaceX-Kapsel sicher gelandet: Touristen kehren nach drei Tagen aus All zurück',
#   'description': 'Es war nicht der erste kommerzielle Passagierflug ins All, aber mit Abstand der längste und weiteste. Drei Tage lang umrundeten vier Weltraumtouristen mit der SpaceX-Kapsel "Crew Dragon" die Erde. Nach der Rückkehr berichten sie von einer "Wahnsinnsreise".',
#   'url': 'https://www.n-tv.de/panorama/Touristen-kehren-nach-drei-Tagen-aus-All-zurueck-article22812774.html',
#   'urlToImage': 'https://bilder2.n-tv.de/img/incoming/crop22812777/8061327535-cImg_16_9-w1200/257196719.jpg',
#   'publishedAt': '2021-09-19T05:33:29Z',
#   'content': 'Es war nicht der erste kommerzielle Passagierflug ins All, aber mit Abstand der längste und weiteste. Drei Tage lang umrundeten vier Weltraumtouristen mit der SpaceX-Kapsel "Crew Dragon" die Erde. Na… [+1953 chars]'},
# ...

# %%
type(art)
# Out:
# list

# %%
for item in art:
    print(item['title','author','source'])
    break
# Out:
# SpaceX-Kapsel sicher gelandet: Touristen kehren nach drei Tagen aus All zurück
